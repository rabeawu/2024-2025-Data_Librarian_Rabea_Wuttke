# %%
import pandas as pd
import json

# %%
searchs = range(1,8)
dataframes = []
for search in searchs:
    filename = f"search{search}.json"

    with open(filename, "r", encoding="utf-8") as f:
        data = json.load(f)
        df = pd.DataFrame(data)
        df = df.loc[df.type == "Publication"]
        df = df[["label", "author", "year", "editor", "pages", "language", "type"]]
        dataframes.append(df)

df_1, df_2, df_3, df_4, df_5, df_6, df_7 = dataframes #Ki-Tipp - nochmal prüfen

# %%
df_1["search term"] = "Douglas Adams"
df_2["search term"] = "Andy Warhol"
df_3["search term"] = "Berthold Brecht"
df_4["search term"] = "Michael Ende"
df_5["search term"] = "Sherlock"
df_6["search term"] = "Forschungsdatenmanagement"
df_7["search term"] = "Python lernen"

# %%
df_all = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7])

# %%
df_all.to_json("search_all.json", orient="records")

# %%
with open("search_all.json", "r") as f:
    j_load = json.load(f)
    print(json.dumps(j_load, indent=2))
# Out:
# [
#   {
#     "label": "Per Anhalter durch die Galaxis: Roman",
#     "author": [
#       "Douglas Adams"
#     ],
#     "year": "1998",
#     "editor": null,
#     "pages": null,
#     "language": null,
#     "type": "Publication",
#     "search term": "Douglas Adams"
#   },
#   {
#     "label": "Per Anhalter durch die Galaxis: Roman",
#     "author": [
#       "Douglas Adams"
#     ],
#     "year": "2009",
#     "editor": null,
#     "pages": null,
#     "language": null,
#     "type": "Publication",
#     "search term": "Douglas Adams"
#   },
#   {
#     "label": "the restaurant at the end of the universe",
#     "author": [
#       "Douglas Adams"
#     ],
#     "year": "1980",
#     "editor": null,
#     "pages": null,
#     "language": null,
#     "type": "Publication",
#     "search term": "Douglas Adams"
#   },
#   {
#     "label": "The hitchhiker's guide to the galaxy",
#     "author": [
#       "Douglas Adams"
#     ],
#     "year": "2009",
#     "editor": null,
# ...
