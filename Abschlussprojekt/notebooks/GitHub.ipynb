# %%
import pandas as pd
import requests
import json
import urllib.parse

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#result_gu = requests.get('https://api.github.com/search/repositories?q="Goethe University"&per_page=100')

suche = ['"university frankfurt"', '"universität frankfurt"', '"goethe universität"', '"goethe university"']
searchmode = ' OR '.join(suche)
query = urllib.parse.quote(searchmode)  # URL-kodiert den Suchbegriff

all_entrys = []

for page in [1, 2]:
    url = f"https://api.github.com/search/repositories?q={query}&per_page=100&page={page}"
    result = requests.get(url)
    data = result.json()
    all_entrys.extend(data.get('items', []))

print(f"Gesamtanzahl gefundener Repositories: {len(all_entrys)}")
# Out:
# Gesamtanzahl gefundener Repositories: 110

# %%
liste = []
for entry in all_entrys:
    liste.append({
        "name": entry["name"],
        "full name": entry["full_name"],
        "url": entry["html_url"],
        "beschreibung": entry["description"],
        "sprache": entry["language"],
        "sterne": entry["stargazers_count"],
        "sprache": entry["language"], 
        "lizenz": entry["license"]["name"] if entry["license"] else None,
        "letztes update": entry["updated_at"]
    })

df_gitgu = pd.DataFrame(liste)
df_gitgu
# Out:
#                                                   name  \
# 0    Real-time-Object-Detection-for-Autonomous-Driv...
# 1                                      bachelor-thesis
# 2    Towards-Explainable-AI-System-for-Traffic-Sign...
# 3             Goethe_University_PhD_thesis_bureaucracy
# 4                                        gu-urlshorter
# 5                                          unification
# 6                                  epi-zusammenfassung
# 7                    Computer-Vision-University-Course
# 8                                           PhD_Thesis
# 9                                     DataScience_SS22
# 10                           MSc05_template_repository
# 11                                          phd-thesis
# 12   seminar-wissenschaftstheorie-und-wissenschafts...
# 13                     Subway-Station-Hazard-Detection
# 14                                           goetheNFT
# 15                                    Intro_HPC_Python
# ...

# %%
df_gitgu = df_gitgu.loc[df_gitgu["lizenz"].isnull() == False]  # löscht Einträge ohne Lizenzangabe
df_gitgu_sw_all = df_gitgu.reset_index(drop=True)  #Index zurücksetzen
df_gitgu_sw_all
# Out:
#                                                  name  \
# 0   Real-time-Object-Detection-for-Autonomous-Driv...
# 1   Towards-Explainable-AI-System-for-Traffic-Sign...
# 2                                       gu-urlshorter
# 3                                 epi-zusammenfassung
# 4                           MSc05_template_repository
# 5                     Subway-Station-Hazard-Detection
# 6                                    Intro_HPC_Python
# 7                                         acoli-dicts
# 8                                    goetheuni-layout
# 9                                       master-thesis
# 10                               tcs.uni-frankfurt.de
# 11                    Bachelor-Thesis-ComputerScience
# 12                                            DBMS-2A
# 13            Reconstruction-of-the-Synagogue-Hoechst
# 14                                       django-clock
# 15  LaTeX-Template-Bachelorthesis-Goethe-Universit...
# ...

# %%
df_gitgu_sw = df_gitgu_sw_all[df_gitgu_sw_all["lizenz"].str.contains('GNU|MIT|BSD|Apache', na=False)] # filtert nach bestimmten Lizenzen
df_gitgu_sw = df_gitgu_sw.reset_index(drop=True)  # neuer Index (Zählung)
df_gitgu_sw
# Out:
#                                                  name  \
# 0   Real-time-Object-Detection-for-Autonomous-Driv...
# 1   Towards-Explainable-AI-System-for-Traffic-Sign...
# 2                                 epi-zusammenfassung
# 3                           MSc05_template_repository
# 4                     Subway-Station-Hazard-Detection
# 5                                    Intro_HPC_Python
# 6                                         acoli-dicts
# 7                                       master-thesis
# 8                                tcs.uni-frankfurt.de
# 9                     Bachelor-Thesis-ComputerScience
# 10                                            DBMS-2A
# 11            Reconstruction-of-the-Synagogue-Hoechst
# 12                                       django-clock
# 13  LaTeX-Template-Bachelorthesis-Goethe-Universit...
# 14                                         DA_project
# 15                                         HPM_Thesis
# ...

# %%
# alle Einträge, wg. Index (findet sich leichter für Vergleiche in GitHub)
df_git = pd.DataFrame(all_entrys)
df_git
# Out:
#              id                           node_id  \
# 0     320820311  MDEwOlJlcG9zaXRvcnkzMjA4MjAzMTE=
# 1     207789720  MDEwOlJlcG9zaXRvcnkyMDc3ODk3MjA=
# 2     321044428  MDEwOlJlcG9zaXRvcnkzMjEwNDQ0Mjg=
# 3      80630281  MDEwOlJlcG9zaXRvcnk4MDYzMDI4MQ==
# 4      40978582  MDEwOlJlcG9zaXRvcnk0MDk3ODU4Mg==
# 5     200397446  MDEwOlJlcG9zaXRvcnkyMDAzOTc0NDY=
# 6     759484614                      R_kgDOLUTQxg
# 7     320811947  MDEwOlJlcG9zaXRvcnkzMjA4MTE5NDc=
# 8      84056969  MDEwOlJlcG9zaXRvcnk4NDA1Njk2OQ==
# 9     508254167                      R_kgDOHktX1w
# 10    502976026                      R_kgDOHfrOGg
# 11     66387235  MDEwOlJlcG9zaXRvcnk2NjM4NzIzNQ==
# 12     57134377  MDEwOlJlcG9zaXRvcnk1NzEzNDM3Nw==
# 13    321043806  MDEwOlJlcG9zaXRvcnkzMjEwNDM4MDY=
# 14    653636509                      R_kgDOJvWznQ
# 15    500225246                      R_kgDOHdDU3g
# 16     84165484  MDEwOlJlcG9zaXRvcnk4NDE2NTQ4NA==
# 17     38940767  MDEwOlJlcG9zaXRvcnkzODk0MDc2Nw==
# ...
