# %%
import pandas as pd
import requests
import json
import urllib.parse

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#result_gu = requests.get('https://api.github.com/search/repositories?q="Goethe University"&per_page=100')

suche = ['"university frankfurt"', '"universität frankfurt"', '"goethe universität"', '"goethe university"']
searchmode = ' OR '.join(suche)
query = urllib.parse.quote(searchmode)  # URL-kodiert den Suchbegriff

all_entrys = []

for page in [1, 2]:
    url = f"https://api.github.com/search/repositories?q={query}&per_page=100&page={page}"
    result = requests.get(url)
    data = result.json()
    all_entrys.extend(data.get('items', []))

print(f"Gesamtanzahl gefundener Repositories: {len(all_entrys)}")
# Out:
# Gesamtanzahl gefundener Repositories: 112

# %%
liste = []
for entry in all_entrys:
    liste.append({
        "dc.title": entry["name"],
        "dc.contributor.author": entry["owner"],
        "dc.identifier.uri": entry["html_url"],
        "dc.description.abstract": entry["description"],
        "dc.relation": entry["topics"],
        "dc.programming.language": entry["language"],
        "dc.licence": entry["license"]["name"] if entry["license"] else None,
        "dc.date.issued": entry["updated_at"],
        "full_name": entry["full_name"]
    })

df_git = pd.DataFrame(liste)

# %%
# Spalte dc.type = Software hinzugfügen
df_git["dc.type"] = "Software"
df_git["monitoring.source"] = "GitHub"

# %%
# dc.relation in string umwandeln
df_git["dc.relation"] = df_git["dc.relation"].apply(
    lambda x: ", ".join(x) if isinstance(x, list)
    else x if pd.notna(x)
    else "")

# %%
#Jahreszahl aus Publication_date extrahieren
def extract_year(value):
    try:
        date = pd.to_datetime(value)  # konvertiert in Datumsstandard
        return date.year  # Gibt nur das Jahr zurück
    except ValueError:
        return value # gibt alten Wert bei Error zurück (ist dann schon JJJJ)

df_git["dc.date.issued"] = df_git["dc.date.issued"].apply(extract_year)

# %%
# Profilname rausfiltern
df_git["dc.contributor.author"] = df_git["dc.contributor.author"].apply(
    lambda x: next(iter(x.values())) if isinstance(x, dict) else x)

# %%
df_git_sw = df_git[df_git["dc.licence"].str.contains('GNU|MIT|BSD|Apache', na=False)] # filtert nach bestimmten Lizenzen
df_git_sw = df_git_sw.reset_index(drop=True)  # neuer Index (Zählung)

# %%
# Überschrift aus README rausziehen

# %%
import base64   #codiert binärdateien zu text (ich brauche ja was aus der readme-datei)
import re   # python modul für reguläre ausdrücke (zb Überschriften)

# %%
GITHUB_TOKEN = "..." # HIER GITHUB-TOKEN EINFÜGEN!! wird gebraucht um eine höhere Anzahl von Abfragen durchführen zu können

headers = {
    "Accept": "application/vnd.github.v3+json",
    "Authorization": f"token {GITHUB_TOKEN}"
}

def get_readme_heading(owner, repo):   # funktion mit 2 argumenten: Benutzer, name des repos
    url = f"https://api.github.com/repos/{owner}/{repo}/readme"  #fragt readme-datei ab

    r = requests.get(url, headers=headers) # abrufen der readme-datei, ergebnis ist ein response-objekt

    if r.status_code == 200:   #prüft, ob Anfrage erfolgreich war (200 heißt erfolgreich)
        data = r.json()
        content_encoded = data.get("content", "")   # holt content-Feld (base64-codierter string)
        content = base64.b64decode(content_encoded).decode("utf-8", errors="ignore")  # verwandelt codierte zeichen in normal lesbaren Text

        match = re.search(r"^#\s+(.+)", content, re.MULTILINE)   # suche nach der ersten Zeile, die mit # beginnt, also einer H1-Überschrift in Markdown.
        if match:
            return match.group(1).strip()   # der Text nach dem #
        else:
            return "keine Überschrift gefunden"
    else:
        return f"kein README ({r.status_code})"


# vorher definierte Funktion auf df_git_sw anwenden, owner+repo benötigt -> full_name
df_git_sw["readme_überschrift"] = df_git_sw["full_name"].apply(lambda full_name: get_readme_heading(*full_name.split("/")))

# %%
# Readme-Titel in dc.title übertragen, wenn brauchbar
df_git_sw.loc[~df_git_sw["readme_überschrift"].isin(["keine Überschrift gefunden", "kein README (404)"]), "dc.title"] = df_git_sw['readme_überschrift']
# Out:
#                                              dc.title dc.contributor.author  \
# 0   Real-time Object Detection for Autonomous Driv...           alen-smajic
# 1   Towards Explainable AI Systems for Traffic Sig...           alen-smajic
# 2                                 EPI Zusammenfassung              Chris022
# 3                           MSc05 template repository           PeerHerholz
# 4   Subway Station Hazard Detection, Goethe Univer...               Psarpei
# 5   Introduction to High-Performance Computing in ...           bsotomayorg
# 6                                         ACoLi Dicts            acoli-repo
# 7   Real-time detection of student engagement usin...               fd-jian
# 8                                tcs.uni-frankfurt.de            goethe-tcs
# 9                                    DBMS Project 2-B                 TheBv
# 10                                    Bachelor Thesis             jfklorenz
# 11  Reconstruction of the Synagogue Höchst, Goethe...           alen-smajic
# 12  LaTeX-Template-Bachelorthesis-Goethe-Universit...         floxdeveloper
# 13                                              Clock              mimischi
# 14                              Data Analysis Project       felixlangschied
# 15                                         HPM_Thesis           Sawbenson15
# 16              Experiment Manual: Alpha Spectroscopy              dspicker
# 17          Mental-Image-decoding. A student project.               JNPauli
# 18  Predicting psychotic disorder with machine lea...               mello-y
# 19                     UBFFM Buchungsjournal Splitter         DavidKrassnig
# 20                                    Quiz Your Skill                rosvid
# 21                       Master Thesis by Jakob Vanek             JayVeezy1
# 22                                             TinyGU          PhysikOnline
# 23                             dronelab - rail safety         ccc-frankfurt
# 24                                         app-geomat         GeoMatDigital
# 25                                              ewba6             jlschnatz
# 26  Smart-Classroom---System-Meets-Life-Science-I-...           FreyA007625
# 27                             Cpp-user-group-meeting           AxelKrypton
# 28                                       PO-App Setup          PhysikOnline
# 29  Visual Saliency as a predictor for emotions - ...               JNPauli
# 30                        Machine-Learning-Algorithms              Ranelkin
# 31                     DB-Data-Challenges (SoSe 2022)              CKolland
# 32                          Frankfurt-GETPathway-WIT1              NiklasAT
# 33                          Neurocognitive Psychology              Gretivan
# 34                           research-internship-2022               tchaase
# 35                                   InsightBundestag     texttechnologylab
# 36        Scraping QIS of Goethe University Frankfurt             Green1407
# 37                          MLPR19 lecture materials:               timtody
#
#                                     dc.identifier.uri  \
# 0   https://github.com/alen-smajic/Real-time-Objec...
# 1   https://github.com/alen-smajic/Towards-Explain...
# 2     https://github.com/Chris022/epi-zusammenfassung
# 3   https://github.com/PeerHerholz/MSc05_template_...
# 4   https://github.com/Psarpei/Subway-Station-Haza...
# 5     https://github.com/bsotomayorg/Intro_HPC_Python
# 6           https://github.com/acoli-repo/acoli-dicts
# 7            https://github.com/fd-jian/master-thesis
# 8   https://github.com/goethe-tcs/tcs.uni-frankfur...
# 9                    https://github.com/TheBv/DBMS-2A
# 10  https://github.com/jfklorenz/Bachelor-Thesis-C...
# 11  https://github.com/alen-smajic/Reconstruction-...
# 12  https://github.com/floxdeveloper/LaTeX-Templat...
# 13           https://github.com/mimischi/django-clock
# 14      https://github.com/felixlangschied/DA_project
# 15          https://github.com/Sawbenson15/HPM_Thesis
# 16  https://github.com/dspicker/ikf-manual-alpha-s...
# 17   https://github.com/JNPauli/Mental-image-decoding
# 18   https://github.com/mello-y/MSc5_research_project
# 19  https://github.com/DavidKrassnig/ubffm-buchung...
# 20          https://github.com/rosvid/quiz-your-skill
# 21             https://github.com/JayVeezy1/MA_thesis
# 22             https://github.com/PhysikOnline/TinyGU
# 23          https://github.com/ccc-frankfurt/dronelab
# 24        https://github.com/GeoMatDigital/app-geomat
# 25         https://github.com/jlschnatz/ewba6_scripts
# 26  https://github.com/FreyA007625/Smart-Classroom...
# 27  https://github.com/AxelKrypton/Cpp-user-group-...
# 28      https://github.com/PhysikOnline/PO-APP_GN_MAT
# 29      https://github.com/JNPauli/Emotional_Machines
# 30  https://github.com/Ranelkin/Machine-Learning-A...
# 31     https://github.com/CKolland/DB-Data-Challenges
# 32  https://github.com/NiklasAT/Frankfurt-GETPathw...
# 33  https://github.com/Gretivan/Neurocognitive_Psy...
# 34  https://github.com/tchaase/research-internship...
# 35  https://github.com/texttechnologylab/InsightBu...
# 36  https://github.com/Green1407/Scraping_QIS_Fran...
# 37                  https://github.com/timtody/mlpr19
#
#                               dc.description.abstract  \
# 0   My Computer Vision project from my Computer Vi...
# 1   This project is part of the CS course 'Systems...
# 2   Meine Zusammenfassung des Moduls: EPI für die ...
# 3   A template repository for projects conducted a...
# 4   This project is part of the CS course 'Systems...
# 5   Extended material of the summer course "Introd...
# 6   3000+ machine-readable open source dictionarie...
# 7   Master thesis written in 2021 for MSc Wirtscha...
# 8   Website of the Theoretical Computer Science Gr...
# 9   Repository for the DBMS Course at the Goethe U...
# 10  Bachelor Thesis in Computer Science, Goethe Un...
# 11  This project is part of the Stolperwege App, w...
# 12  Unofficial LaTeX template for a bachelor thesi...
# 13  A tool for student assistans at the Goethe Uni...
# 14  A template for data analysis projects for the ...
# 15                           Goethe University Thesis
# 16  The LaTeX project of the experiment-manual for...
# 17  The research project is part of the MSc05 modu...
# 18  This repository is for my research project for...
# 19  This is a small script to split up the bulk PD...
# 20  "Quiz Your Skill" is a simple quiz app which w...
# 21  This Code was used for my Masters Thesis 'Anal...
# 22          URL Shortener for Goethe University pages
# 23  Code and documentation to our project drone la...
# 24   GeoMat-App for students of the Goethe University
# 25  Analysis Scripts for EW-BA6 Course at Goethe U...
# 26                                               None
# 27  A space to support the C++ user group meeting ...
# 28  PO-APP connected with the elearning-portal  Go...
# 29  The Aim of this master thesis was to use salie...
# 30  Implementation of Machine Learning Alghoritms ...
# 31  Goehte University Frankfurt - Data analysis pr...
# 32  Fiji macro and workflow used in my Bachelor’s ...
# 33  This is a  Neurocognitive psychology project a...
# 34  Repository for the research internship in neur...
# 35  Java classes for the implementation of exercis...
# 36  This is a university project in which data is ...
# 37  Lecture materials for the "Pattern Analysis an...
#
#                                           dc.relation dc.programming.language  \
# 0   bdd100k, berkeley-deep-drive, cnn, computer-sc...        Jupyter Notebook
# 1   autonomous-driving, blender, classification, c...                      C#
# 2                                                                        None
# 3                                                                        None
# 4   blender, computer-vision, csharp, deep-learnin...        Jupyter Notebook
# 5   high-performance-computing, matplotlib-exercis...        Jupyter Notebook
# 6   dataset, dictionary, open-source, rdf, transla...                   Shell
# 7                                                                        None
# 8                                                                        HTML
# 9                                                                  TypeScript
# 10  bachelor, bachelor-thesis, computer-science, c...                     TeX
# 11  3d-model, 3d-reconstruction, blender, germany,...                    None
# 12                                                                        TeX
# 13                                                                     Python
# 14                                                                       None
# 15                                                                       HTML
# 16                                                                        TeX
# 17                                                           Jupyter Notebook
# 18                                                           Jupyter Notebook
# 19                                                                     Python
# 20                                                                       Java
# 21                                                           Jupyter Notebook
# 22  angular, angular5, goethe-university, material...              TypeScript
# 23                                                           Jupyter Notebook
# 24                                                                 TypeScript
# 25                                                                       HTML
# 26                                                           Jupyter Notebook
# 27                                                                        C++
# 28                                                                 TypeScript
# 29                                                           Jupyter Notebook
# 30                                                                     Python
# 31                                                                     Python
# 32                                                                     Python
# 33                                                           Jupyter Notebook
# 34                                                           Jupyter Notebook
# 35                                                                       Java
# 36                                                                     Python
# 37                                                           Jupyter Notebook
#
#                                  dc.licence  dc.date.issued  \
# 0                               MIT License            2025
# 1                               MIT License            2025
# 2           GNU General Public License v3.0            2025
# 3   BSD 3-Clause "New" or "Revised" License            2022
# 4                               MIT License            2025
# 5                               MIT License            2025
# 6                        Apache License 2.0            2025
# 7           GNU General Public License v3.0            2021
# 8           GNU General Public License v3.0            2025
# 9    GNU Lesser General Public License v3.0            2024
# 10                              MIT License            2020
# 11                              MIT License            2021
# 12                              MIT License            2025
# 13                              MIT License            2021
# 14          GNU General Public License v3.0            2024
# 15                              MIT License            2022
# 16          GNU General Public License v3.0            2024
# 17  BSD 3-Clause "New" or "Revised" License            2023
# 18  BSD 3-Clause "New" or "Revised" License            2023
# 19                              MIT License            2023
# 20          GNU General Public License v3.0            2022
# 21          GNU General Public License v3.0            2024
# 22                              MIT License            2023
# 23                              MIT License            2021
# 24          GNU General Public License v3.0            2023
# 25                              MIT License            2025
# 26                              MIT License            2021
# 27          GNU General Public License v3.0            2025
# 28                              MIT License            2023
# 29                              MIT License            2023
# 30                              MIT License            2024
# 31                              MIT License            2024
# 32                              MIT License            2025
# 33  BSD 3-Clause "New" or "Revised" License            2023
# 34  BSD 3-Clause "New" or "Revised" License            2023
# 35   GNU Affero General Public License v3.0            2023
# 36                              MIT License            2025
# 37          GNU General Public License v3.0            2020
#
#                                             full_name   dc.type  \
# 0   alen-smajic/Real-time-Object-Detection-for-Aut...  Software
# 1   alen-smajic/Towards-Explainable-AI-System-for-...  Software
# 2                        Chris022/epi-zusammenfassung  Software
# 3               PeerHerholz/MSc05_template_repository  Software
# 4             Psarpei/Subway-Station-Hazard-Detection  Software
# 5                        bsotomayorg/Intro_HPC_Python  Software
# 6                              acoli-repo/acoli-dicts  Software
# 7                               fd-jian/master-thesis  Software
# 8                     goethe-tcs/tcs.uni-frankfurt.de  Software
# 9                                       TheBv/DBMS-2A  Software
# 10          jfklorenz/Bachelor-Thesis-ComputerScience  Software
# 11  alen-smajic/Reconstruction-of-the-Synagogue-Ho...  Software
# 12  floxdeveloper/LaTeX-Template-Bachelorthesis-Go...  Software
# 13                              mimischi/django-clock  Software
# 14                         felixlangschied/DA_project  Software
# 15                             Sawbenson15/HPM_Thesis  Software
# 16             dspicker/ikf-manual-alpha-spectroscopy  Software
# 17                      JNPauli/Mental-image-decoding  Software
# 18                      mello-y/MSc5_research_project  Software
# 19       DavidKrassnig/ubffm-buchungsjournal-splitter  Software
# 20                             rosvid/quiz-your-skill  Software
# 21                                JayVeezy1/MA_thesis  Software
# 22                                PhysikOnline/TinyGU  Software
# 23                             ccc-frankfurt/dronelab  Software
# 24                           GeoMatDigital/app-geomat  Software
# 25                            jlschnatz/ewba6_scripts  Software
# 26  FreyA007625/Smart-Classroom---System-Meets-Lif...  Software
# 27                 AxelKrypton/Cpp-user-group-meeting  Software
# 28                         PhysikOnline/PO-APP_GN_MAT  Software
# 29                         JNPauli/Emotional_Machines  Software
# 30               Ranelkin/Machine-Learning-Algorithms  Software
# 31                        CKolland/DB-Data-Challenges  Software
# 32                 NiklasAT/Frankfurt-GETPathway-WIT1  Software
# 33                 Gretivan/Neurocognitive_Psychology  Software
# 34                   tchaase/research-internship-2022  Software
# 35                 texttechnologylab/InsightBundestag  Software
# 36                   Green1407/Scraping_QIS_Frankfurt  Software
# 37                                     timtody/mlpr19  Software
#
#    monitoring.source                                 readme_überschrift
# 0             GitHub  Real-time Object Detection for Autonomous Driv...
# 1             GitHub  Towards Explainable AI Systems for Traffic Sig...
# 2             GitHub                                EPI Zusammenfassung
# 3             GitHub                          MSc05 template repository
# 4             GitHub  Subway Station Hazard Detection, Goethe Univer...
# 5             GitHub  Introduction to High-Performance Computing in ...
# 6             GitHub                                        ACoLi Dicts
# 7             GitHub  Real-time detection of student engagement usin...
# 8             GitHub                               tcs.uni-frankfurt.de
# 9             GitHub                                   DBMS Project 2-B
# 10            GitHub                                    Bachelor Thesis
# 11            GitHub  Reconstruction of the Synagogue Höchst, Goethe...
# 12            GitHub  LaTeX-Template-Bachelorthesis-Goethe-Universit...
# 13            GitHub                                              Clock
# 14            GitHub                              Data Analysis Project
# 15            GitHub                                         HPM_Thesis
# 16            GitHub              Experiment Manual: Alpha Spectroscopy
# 17            GitHub          Mental-Image-decoding. A student project.
# 18            GitHub  Predicting psychotic disorder with machine lea...
# 19            GitHub                     UBFFM Buchungsjournal Splitter
# 20            GitHub                                    Quiz Your Skill
# 21            GitHub                       Master Thesis by Jakob Vanek
# 22            GitHub                         keine Überschrift gefunden
# 23            GitHub                             dronelab - rail safety
# 24            GitHub                         keine Überschrift gefunden
# 25            GitHub                                              ewba6
# 26            GitHub  Smart-Classroom---System-Meets-Life-Science-I-...
# 27            GitHub                         keine Überschrift gefunden
# 28            GitHub                                       PO-App Setup
# 29            GitHub  Visual Saliency as a predictor for emotions - ...
# 30            GitHub                         keine Überschrift gefunden
# 31            GitHub                     DB-Data-Challenges (SoSe 2022)
# 32            GitHub                                  kein README (404)
# 33            GitHub                          Neurocognitive Psychology
# 34            GitHub                           research-internship-2022
# 35            GitHub                                   InsightBundestag
# 36            GitHub        Scraping QIS of Goethe University Frankfurt
# 37            GitHub                          MLPR19 lecture materials:

# %%
#nicht mehr benötigte Spalten löschen
df_git_clean = df_git_sw.drop(columns = ["full_name", "readme_überschrift"])
df_git_clean
# Out:
#                                              dc.title dc.contributor.author  \
# 0   Real-time Object Detection for Autonomous Driv...           alen-smajic
# 1   Towards Explainable AI Systems for Traffic Sig...           alen-smajic
# 2                                 EPI Zusammenfassung              Chris022
# 3                           MSc05 template repository           PeerHerholz
# 4   Subway Station Hazard Detection, Goethe Univer...               Psarpei
# 5   Introduction to High-Performance Computing in ...           bsotomayorg
# 6                                         ACoLi Dicts            acoli-repo
# 7   Real-time detection of student engagement usin...               fd-jian
# 8                                tcs.uni-frankfurt.de            goethe-tcs
# 9                                    DBMS Project 2-B                 TheBv
# 10                                    Bachelor Thesis             jfklorenz
# 11  Reconstruction of the Synagogue Höchst, Goethe...           alen-smajic
# 12  LaTeX-Template-Bachelorthesis-Goethe-Universit...         floxdeveloper
# 13                                              Clock              mimischi
# 14                              Data Analysis Project       felixlangschied
# 15                                         HPM_Thesis           Sawbenson15
# 16              Experiment Manual: Alpha Spectroscopy              dspicker
# 17          Mental-Image-decoding. A student project.               JNPauli
# 18  Predicting psychotic disorder with machine lea...               mello-y
# 19                     UBFFM Buchungsjournal Splitter         DavidKrassnig
# 20                                    Quiz Your Skill                rosvid
# 21                       Master Thesis by Jakob Vanek             JayVeezy1
# 22                                             TinyGU          PhysikOnline
# 23                             dronelab - rail safety         ccc-frankfurt
# 24                                         app-geomat         GeoMatDigital
# 25                                              ewba6             jlschnatz
# 26  Smart-Classroom---System-Meets-Life-Science-I-...           FreyA007625
# 27                             Cpp-user-group-meeting           AxelKrypton
# 28                                       PO-App Setup          PhysikOnline
# 29  Visual Saliency as a predictor for emotions - ...               JNPauli
# 30                        Machine-Learning-Algorithms              Ranelkin
# 31                     DB-Data-Challenges (SoSe 2022)              CKolland
# 32                          Frankfurt-GETPathway-WIT1              NiklasAT
# 33                          Neurocognitive Psychology              Gretivan
# 34                           research-internship-2022               tchaase
# 35                                   InsightBundestag     texttechnologylab
# 36        Scraping QIS of Goethe University Frankfurt             Green1407
# 37                          MLPR19 lecture materials:               timtody
#
#                                     dc.identifier.uri  \
# 0   https://github.com/alen-smajic/Real-time-Objec...
# 1   https://github.com/alen-smajic/Towards-Explain...
# 2     https://github.com/Chris022/epi-zusammenfassung
# 3   https://github.com/PeerHerholz/MSc05_template_...
# 4   https://github.com/Psarpei/Subway-Station-Haza...
# 5     https://github.com/bsotomayorg/Intro_HPC_Python
# 6           https://github.com/acoli-repo/acoli-dicts
# 7            https://github.com/fd-jian/master-thesis
# 8   https://github.com/goethe-tcs/tcs.uni-frankfur...
# 9                    https://github.com/TheBv/DBMS-2A
# 10  https://github.com/jfklorenz/Bachelor-Thesis-C...
# 11  https://github.com/alen-smajic/Reconstruction-...
# 12  https://github.com/floxdeveloper/LaTeX-Templat...
# 13           https://github.com/mimischi/django-clock
# 14      https://github.com/felixlangschied/DA_project
# 15          https://github.com/Sawbenson15/HPM_Thesis
# 16  https://github.com/dspicker/ikf-manual-alpha-s...
# 17   https://github.com/JNPauli/Mental-image-decoding
# 18   https://github.com/mello-y/MSc5_research_project
# 19  https://github.com/DavidKrassnig/ubffm-buchung...
# 20          https://github.com/rosvid/quiz-your-skill
# 21             https://github.com/JayVeezy1/MA_thesis
# 22             https://github.com/PhysikOnline/TinyGU
# 23          https://github.com/ccc-frankfurt/dronelab
# 24        https://github.com/GeoMatDigital/app-geomat
# 25         https://github.com/jlschnatz/ewba6_scripts
# 26  https://github.com/FreyA007625/Smart-Classroom...
# 27  https://github.com/AxelKrypton/Cpp-user-group-...
# 28      https://github.com/PhysikOnline/PO-APP_GN_MAT
# 29      https://github.com/JNPauli/Emotional_Machines
# 30  https://github.com/Ranelkin/Machine-Learning-A...
# 31     https://github.com/CKolland/DB-Data-Challenges
# 32  https://github.com/NiklasAT/Frankfurt-GETPathw...
# 33  https://github.com/Gretivan/Neurocognitive_Psy...
# 34  https://github.com/tchaase/research-internship...
# 35  https://github.com/texttechnologylab/InsightBu...
# 36  https://github.com/Green1407/Scraping_QIS_Fran...
# 37                  https://github.com/timtody/mlpr19
#
#                               dc.description.abstract  \
# 0   My Computer Vision project from my Computer Vi...
# 1   This project is part of the CS course 'Systems...
# 2   Meine Zusammenfassung des Moduls: EPI für die ...
# 3   A template repository for projects conducted a...
# 4   This project is part of the CS course 'Systems...
# 5   Extended material of the summer course "Introd...
# 6   3000+ machine-readable open source dictionarie...
# 7   Master thesis written in 2021 for MSc Wirtscha...
# 8   Website of the Theoretical Computer Science Gr...
# 9   Repository for the DBMS Course at the Goethe U...
# 10  Bachelor Thesis in Computer Science, Goethe Un...
# 11  This project is part of the Stolperwege App, w...
# 12  Unofficial LaTeX template for a bachelor thesi...
# 13  A tool for student assistans at the Goethe Uni...
# 14  A template for data analysis projects for the ...
# 15                           Goethe University Thesis
# 16  The LaTeX project of the experiment-manual for...
# 17  The research project is part of the MSc05 modu...
# 18  This repository is for my research project for...
# 19  This is a small script to split up the bulk PD...
# 20  "Quiz Your Skill" is a simple quiz app which w...
# 21  This Code was used for my Masters Thesis 'Anal...
# 22          URL Shortener for Goethe University pages
# 23  Code and documentation to our project drone la...
# 24   GeoMat-App for students of the Goethe University
# 25  Analysis Scripts for EW-BA6 Course at Goethe U...
# 26                                               None
# 27  A space to support the C++ user group meeting ...
# 28  PO-APP connected with the elearning-portal  Go...
# 29  The Aim of this master thesis was to use salie...
# 30  Implementation of Machine Learning Alghoritms ...
# 31  Goehte University Frankfurt - Data analysis pr...
# 32  Fiji macro and workflow used in my Bachelor’s ...
# 33  This is a  Neurocognitive psychology project a...
# 34  Repository for the research internship in neur...
# 35  Java classes for the implementation of exercis...
# 36  This is a university project in which data is ...
# 37  Lecture materials for the "Pattern Analysis an...
#
#                                           dc.relation dc.programming.language  \
# 0   bdd100k, berkeley-deep-drive, cnn, computer-sc...        Jupyter Notebook
# 1   autonomous-driving, blender, classification, c...                      C#
# 2                                                                        None
# 3                                                                        None
# 4   blender, computer-vision, csharp, deep-learnin...        Jupyter Notebook
# 5   high-performance-computing, matplotlib-exercis...        Jupyter Notebook
# 6   dataset, dictionary, open-source, rdf, transla...                   Shell
# 7                                                                        None
# 8                                                                        HTML
# 9                                                                  TypeScript
# 10  bachelor, bachelor-thesis, computer-science, c...                     TeX
# 11  3d-model, 3d-reconstruction, blender, germany,...                    None
# 12                                                                        TeX
# 13                                                                     Python
# 14                                                                       None
# 15                                                                       HTML
# 16                                                                        TeX
# 17                                                           Jupyter Notebook
# 18                                                           Jupyter Notebook
# 19                                                                     Python
# 20                                                                       Java
# 21                                                           Jupyter Notebook
# 22  angular, angular5, goethe-university, material...              TypeScript
# 23                                                           Jupyter Notebook
# 24                                                                 TypeScript
# 25                                                                       HTML
# 26                                                           Jupyter Notebook
# 27                                                                        C++
# 28                                                                 TypeScript
# 29                                                           Jupyter Notebook
# 30                                                                     Python
# 31                                                                     Python
# 32                                                                     Python
# 33                                                           Jupyter Notebook
# 34                                                           Jupyter Notebook
# 35                                                                       Java
# 36                                                                     Python
# 37                                                           Jupyter Notebook
#
#                                  dc.licence  dc.date.issued   dc.type  \
# 0                               MIT License            2025  Software
# 1                               MIT License            2025  Software
# 2           GNU General Public License v3.0            2025  Software
# 3   BSD 3-Clause "New" or "Revised" License            2022  Software
# 4                               MIT License            2025  Software
# 5                               MIT License            2025  Software
# 6                        Apache License 2.0            2025  Software
# 7           GNU General Public License v3.0            2021  Software
# 8           GNU General Public License v3.0            2025  Software
# 9    GNU Lesser General Public License v3.0            2024  Software
# 10                              MIT License            2020  Software
# 11                              MIT License            2021  Software
# 12                              MIT License            2025  Software
# 13                              MIT License            2021  Software
# 14          GNU General Public License v3.0            2024  Software
# 15                              MIT License            2022  Software
# 16          GNU General Public License v3.0            2024  Software
# 17  BSD 3-Clause "New" or "Revised" License            2023  Software
# 18  BSD 3-Clause "New" or "Revised" License            2023  Software
# 19                              MIT License            2023  Software
# 20          GNU General Public License v3.0            2022  Software
# 21          GNU General Public License v3.0            2024  Software
# 22                              MIT License            2023  Software
# 23                              MIT License            2021  Software
# 24          GNU General Public License v3.0            2023  Software
# 25                              MIT License            2025  Software
# 26                              MIT License            2021  Software
# 27          GNU General Public License v3.0            2025  Software
# 28                              MIT License            2023  Software
# 29                              MIT License            2023  Software
# 30                              MIT License            2024  Software
# 31                              MIT License            2024  Software
# 32                              MIT License            2025  Software
# 33  BSD 3-Clause "New" or "Revised" License            2023  Software
# 34  BSD 3-Clause "New" or "Revised" License            2023  Software
# 35   GNU Affero General Public License v3.0            2023  Software
# 36                              MIT License            2025  Software
# 37          GNU General Public License v3.0            2020  Software
#
#    monitoring.source
# 0             GitHub
# 1             GitHub
# 2             GitHub
# 3             GitHub
# 4             GitHub
# 5             GitHub
# 6             GitHub
# 7             GitHub
# 8             GitHub
# 9             GitHub
# 10            GitHub
# 11            GitHub
# 12            GitHub
# 13            GitHub
# 14            GitHub
# 15            GitHub
# 16            GitHub
# 17            GitHub
# 18            GitHub
# 19            GitHub
# 20            GitHub
# 21            GitHub
# 22            GitHub
# 23            GitHub
# 24            GitHub
# 25            GitHub
# 26            GitHub
# 27            GitHub
# 28            GitHub
# 29            GitHub
# 30            GitHub
# 31            GitHub
# 32            GitHub
# 33            GitHub
# 34            GitHub
# 35            GitHub
# 36            GitHub
# 37            GitHub

# %%
#löscht Thesis
df_git_clean = df_git_clean[~df_git_clean["dc.title"].str.contains('thesis|Thesis')]
#df_git_clean = df_git_sw.reset_index(drop=True)  # neuer Index (Zählung)

df_git_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dc.title                 34 non-null     object
#  1   dc.contributor.author    34 non-null     object
#  2   dc.identifier.uri        34 non-null     object
#  3   dc.description.abstract  33 non-null     object
#  4   dc.relation              34 non-null     object
#  5   dc.programming.language  29 non-null     object
#  6   dc.licence               34 non-null     object
#  7   dc.date.issued           34 non-null     int64
#  8   dc.type                  34 non-null     object
#  9   monitoring.source        34 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 2.9+ KB

# %%
# Dublettenprüfung
df_git_clean = df_git_clean.drop_duplicates(subset = ["dc.title"], keep = "first")

# %%
df_git_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dc.title                 34 non-null     object
#  1   dc.contributor.author    34 non-null     object
#  2   dc.identifier.uri        34 non-null     object
#  3   dc.description.abstract  33 non-null     object
#  4   dc.relation              34 non-null     object
#  5   dc.programming.language  29 non-null     object
#  6   dc.licence               34 non-null     object
#  7   dc.date.issued           34 non-null     int64
#  8   dc.type                  34 non-null     object
#  9   monitoring.source        34 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 2.9+ KB

# %%
df_git_clean.to_csv("data_github.csv")

# %%
#übrige Einträge anschauen, was das für Lizenzen sind, könnte - je nach Menge händisch geprüft werden
df_gitgu_check = df_gitgu_sw_all[~df_gitgu_sw_all["lizenz"].str.contains('GNU|MIT|BSD|Apache')] # gibt übrige Einträge aus: ~ ist not-Operator
df_gitgu_check
# Out:
#                                     name  \
# 2                          gu-urlshorter
# 8                       goetheuni-layout
# 17  Ensemble_Learning_Image_Transformers
# 30                     grading-gu-quarto
# 38   scene_orientation_contextual_cueing
# 40            website_editing-film-music
#
#                                             full name  \
# 2                      PhysikOnline-FFM/gu-urlshorter
# 8                              svenk/goetheuni-layout
# 17  cr-heidemann/Ensemble_Learning_Image_Transformers
# 30                         tisprang/grading-gu-quarto
# 38      jlschnatz/scene_orientation_contextual_cueing
# 40    korngold-werkausgabe/website_editing-film-music
#
#                                                   url  \
# 2   https://github.com/PhysikOnline-FFM/gu-urlshorter
# 8           https://github.com/svenk/goetheuni-layout
# 17  https://github.com/cr-heidemann/Ensemble_Learn...
# 30      https://github.com/tisprang/grading-gu-quarto
# 38  https://github.com/jlschnatz/scene_orientation...
# 40  https://github.com/korngold-werkausgabe/websit...
#
#                                          beschreibung     sprache  sterne  \
# 2      URL-Shortener for Goethe University, Frankfurt         PHP       4
# 8   The webdesign of Goethe-Universität Frankfurt,...         PHP       1
# 17  This repo was created for my master thesis abo...      Python       0
# 30  Quarto template for grading term papers at Goe...         TeX       0
# 38  Data and Analysis Scripts of a study conducted...         TeX       0
# 40  This is the repository for the conference webs...  TypeScript       0
#
#                                   lizenz        letztes update
# 2                                  Other  2023-01-28T11:26:14Z
# 8   Creative Commons Zero v1.0 Universal  2020-12-13T11:33:07Z
# 17                                 Other  2024-08-25T08:52:43Z
# 30  Creative Commons Zero v1.0 Universal  2024-10-30T09:56:11Z
# 38                                 Other  2023-11-17T22:50:46Z
# 40                                 Other  2025-05-07T16:04:00Z
