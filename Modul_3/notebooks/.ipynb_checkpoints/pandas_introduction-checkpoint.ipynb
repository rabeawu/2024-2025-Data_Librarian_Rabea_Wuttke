# %%
import pandas as pd

# %%
x = pd.Series([34, 12, 23, 45])
print(x)
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64

# %%
x.dtype
# Out:
# dtype('int64')

# %%
data = {'month': ['Jan', 'Feb', 'Mar', 'Apr'],
        'temp': [-5, 2, 3, 5],
         'below_zero': [True, False, False, False],
           'year': 2020}
df = pd.DataFrame(data)
print(df)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %%
df = pd.read_csv("2024-2025-Data_Librarian_Rabea_Wuttke/Modul_3/data/Library_Usage.csv", low_memory=False, na_values="Null")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450359 entries, 0 to 450358
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Patron Type Definition        450359 non-null  object
#  1   Total Checkouts               450359 non-null  int64
#  2   Total Renewals                450359 non-null  int64
#  3   Age Range                     449849 non-null  object
#  4   Home Library Definition       450329 non-null  object
#  5   Circulation Active Month      410042 non-null  object
#  6   Circulation Active Year       410042 non-null  float64
#  7   Notice Preference Definition  447044 non-null  object
#  8   Provided Email Address        450359 non-null  bool
#  9   Year Patron Registered        450359 non-null  int64
#  10  Within San Francisco County   450138 non-null  object
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 34.8+ MB

# %%
# 1. 11 Merkmale
# 2. Stichprobengröße: 450359
# 3. Merkmalsträger/statistische Einheit: Bibliotheksnutzer*in
# 4. 2016 - 2024 (laut website)

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 450354    0
# 450355    0
# 450356    0
# 450357    0
# 450358    0
# Name: Total Renewals, Length: 450359, dtype: int64
#         Total Renewals  Total Checkouts
# 0                    0                5
# 1                    0                0
# 2                    0                0
# 3                    1                1
# 4                    0                0
# ...                ...              ...
# 450354               0                0
# 450355               0                0
# 450356               0                0
# 450357               0                0
# 450358               0                0
#
# [450359 rows x 2 columns]

# %%
import numpy as np

# %%
df['is_adult'] = df['Patron Type Definition'] == 'Adult'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)

# %%
pd.to_numeric(df['Circulation Active Year'], errors='coerce')
# Out:
# 0         2022.0
# 1         2023.0
# 2         2024.0
# 3         2022.0
# 4         2024.0
#            ...
# 450354       NaN
# 450355    2022.0
# 450356    2022.0
# 450357    2022.0
# 450358    2023.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%b"
)

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

# %%
df['Membership Duration'] = (df['Circulation Active Year'] - df['Year Patron Registered'])*12 + df['Circulation Active Month']

# %%
df['Membership Duration'] = df['Membership Duration'].fillna(0)

# %%
filter3 = (df['Age Range'] == "60 to 64 years") & (df['Circulation Active Year'] == 2016)

# %%
len(df.loc[filter3])
# Out:
# 16

# %%
(df["Membership Duration"] == 0).mean()
# Out:
# 0.08952191473913033

# %%
print(len(df[df['Membership Duration'] == 0])/len(df))
# Out:
# 0.08952191473913033

# %%
filter_0 = (df["Membership Duration"] == 0)
df.loc[filter_0]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 14               Teacher Card                0               0
# 17               Teacher Card                0               0
# 36                     Senior                0               0
# 93                     Senior                0               0
# 127                    Senior                0               0
# ...                       ...              ...             ...
# 450321    Digital Access Card                0               0
# 450324    Digital Access Card                0               0
# 450339    Digital Access Card                0               0
# 450340    Digital Access Card                0               0
# 450354    Digital Access Card                0               0
#
#                 Age Range Home Library Definition  Circulation Active Month  \
# 14           0 to 9 years                    Main                       NaN
# ...

# %%
filter_richm = (df['Home Library Definition'] == "Richmond")
df.loc[filter_richm].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21433 entries, 3 to 450291
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Patron Type Definition        21433 non-null  object
#  1   Total Checkouts               21433 non-null  int64
#  2   Total Renewals                21433 non-null  int64
#  3   Age Range                     21422 non-null  object
#  4   Home Library Definition       21433 non-null  object
#  5   Circulation Active Month      20676 non-null  float64
#  6   Circulation Active Year       20676 non-null  float64
#  7   Notice Preference Definition  21386 non-null  object
#  8   Provided Email Address        21433 non-null  bool
#  9   Year Patron Registered        21433 non-null  int64
#  10  Within San Francisco County   21427 non-null  object
#  11  is_adult                      21433 non-null  bool
# ...

# %%
filter_20000 = (df['Total Checkouts'] >= 20000)
df.loc[filter_20000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 60282 to 293994
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Patron Type Definition        7 non-null      object
#  1   Total Checkouts               7 non-null      int64
#  2   Total Renewals                7 non-null      int64
#  3   Age Range                     7 non-null      object
#  4   Home Library Definition       7 non-null      object
#  5   Circulation Active Month      7 non-null      float64
#  6   Circulation Active Year       7 non-null      float64
#  7   Notice Preference Definition  7 non-null      object
#  8   Provided Email Address        7 non-null      bool
#  9   Year Patron Registered        7 non-null      int64
#  10  Within San Francisco County   7 non-null      object
#  11  is_adult                      7 non-null      bool
# ...

# %%
df["Age Range"].unique()
# Out:
# array(['75 years and over', '45 to 54 years', '55 to 59 years',
#        '20 to 24 years', '65 to 74 years', '10 to 19 years',
#        '25 to 34 years', '60 to 64 years', '35 to 44 years',
#        '0 to 9 years', nan], dtype=object)

# %%
filter_kids = (df["Age Range"] == '0 to 9 years')

# %%
df.loc[filter_kids]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals     Age Range  \
# 14               Teacher Card                0               0  0 to 9 years
# 1067                    Adult                0               0  0 to 9 years
# 1487                 Juvenile                0               0  0 to 9 years
# 1488                 Juvenile                0               0  0 to 9 years
# 1491                 Juvenile                0               0  0 to 9 years
# ...                       ...              ...             ...           ...
# 450241               Juvenile                0               0  0 to 9 years
# 450244               Juvenile                2               2  0 to 9 years
# 450245               Juvenile                0               0  0 to 9 years
# 450246               Juvenile                2               2  0 to 9 years
# 450247               Juvenile               11              15  0 to 9 years
#
# ...

# %%
print(len(df[df['Age Range'].isna()]))
# Out:
# 510

# %%
df.head(100)
# Out:
#    Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                  Senior                5               0  75 years and over
# 1                   Adult                0               0     45 to 54 years
# 2                   Adult                0               0     55 to 59 years
# 3                 Welcome                1               1     20 to 24 years
# 4                  Senior                0               0     65 to 74 years
# ..                    ...              ...             ...                ...
# 95                 Senior               81              37  75 years and over
# 96                 Senior                0               0     65 to 74 years
# 97                 Senior                0               0     65 to 74 years
# 98                 Senior                0               0     65 to 74 years
# 99                 Senior                1               0  75 years and over
#
# ...

# %%
df.shape
# Out:
# (450359, 14)
