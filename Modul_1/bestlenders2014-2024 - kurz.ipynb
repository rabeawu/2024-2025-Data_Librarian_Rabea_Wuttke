# %%
import pandas as pd
import urllib.request

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=20"

years = range(14,25)

file_names = [f"checkouts{year}_file.csv" for year in years]

# %%
for year, file_name in zip(years, file_names):
    urllib.request.urlretrieve(f"{url}{year}", file_name)

# %%
bestlenders = []
for file_name, year in zip(file_names, years):
    df = pd.read_csv(file_name)
    bestlender = df[df["checkouts"] == df["checkouts"].max()]
    bestlender.to_csv(f"bestlender{year}.csv", index=False)
    bestlenders.append(bestlender)

# %%
bestlender2014_2024 = pd.concat(bestlenders, axis=0, ignore_index=True)

# %%
bestlender2014_2024
# Out:
#    usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0    Physical      Horizon         BOOK          2014              1
# 1    Physical      Horizon    VIDEODISC          2015              1
# 2     Digital        Zinio     MAGAZINE          2016             10
# 3     Digital    OverDrive        EBOOK          2017              1
# 4    Physical      Horizon         BOOK          2018              1
# 5    Physical      Horizon         BOOK          2019              1
# 6    Physical      Horizon         BOOK          2020              1
# 7    Physical      Horizon     REGPRINT          2021              1
# 8     Digital    OverDrive        EBOOK          2022              1
# 9     Digital    OverDrive        EBOOK          2023              1
# 10    Digital    OverDrive    AUDIOBOOK          2024              4
#
#     checkouts                                              title  \
# 0          91             Americanah / Chimamanda Ngozi Adichie.
# 1         105  Downton Abbey [videorecording] / a Carnival/Ma...
# 2         141                                           Newsweek
# 3         117  The Trespasser: Dublin Murder Squad Series, Bo...
# 4          95               Leonardo da Vinci / Walter Isaacson.
# 5         458                Less : a novel / Andrew Sean Greer.
# 6         355                           Exhalation / Ted Chiang.
# 7         270                       Guinness world records 2021.
# 8          74                      Before We Were Yours: A Novel
# 9         133                    Wrong Place Wrong Time: A Novel
# 10        102                                 Bride (unabridged)
#
#              isbn                           creator  \
# 0             NaN  Adichie, Chimamanda Ngozi, 1977-
# 1             NaN                               NaN
# 2             NaN                               NaN
# 3             NaN                       Tana French
# 4             NaN                  Isaacson, Walter
# 5             NaN                Greer, Andrew Sean
# 6             NaN                       Chiang, Ted
# 7             NaN                               NaN
# 8             NaN                      Lisa Wingate
# 9   9780063252363                Gillian McAllister
# 10  9780593825556                     Ali Hazelwood
#
#                                              subjects  \
# 0   Immigrants Fiction, Refugees Fiction, Nigerian...
# 1   Country life Drama, Families Drama, Household ...
# 2                                                 NaN
# 3                          Fiction, Mystery, Thriller
# 4   Leonardo da Vinci 1452 1519, Artists Italy Bio...
# 5   Authors Fiction, Gay men Fiction, Voyages and ...
# 6                      Science fiction, Short stories
# 7   World records, Curiosities and wonders, Questi...
# 8             Fiction, Literature, Historical Fiction
# 9                         Fiction, Suspense, Thriller
# 10                          Fantasy, Fiction, Romance
#
#                           publisher publicationyear
# 0                  Alfred A. Knopf,           2013.
# 1          PBS Distribution ; WGBH,          c2011.
# 2                               NaN             NaN
# 3         Penguin Group (USA), Inc.            2016
# 4                 Simon & Schuster,           2017.
# 5        Little, Brown and Company,           2017.
# 6                  Alfred A. Knopf,           2019.
# 7   Guinness World Records Limited,          [2020]
# 8                Random House, Inc.            2017
# 9     HarperCollins Publishers Inc.            2022
# 10                    Books on Tape            2024

# %%
bestlender2014_2024.to_csv("bestlender2014_2024.csv", index=False)
