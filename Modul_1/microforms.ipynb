# %%
import pandas as pd
import urllib.request

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?materialtype=MICROFORM&$limit=10000"
microf_file = "microffile.csv"
urllib.request.urlretrieve(url, microf_file)
# Out:
# ('microffile.csv', <http.client.HTTPMessage at 0x7b0e56bd7b60>)

# %%
microf_df = pd.read_csv(microf_file)
microf_df
# Out:
#     usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0     Physical      Horizon    MICROFORM          2005              4
# 1     Physical      Horizon    MICROFORM          2005              4
# 2     Physical      Horizon    MICROFORM          2005              4
# 3     Physical      Horizon    MICROFORM          2005              4
# 4     Physical      Horizon    MICROFORM          2005              7
# ..         ...          ...          ...           ...            ...
# 255   Physical      Horizon    MICROFORM          2024              4
# 256   Physical      Horizon    MICROFORM          2024              9
# 257   Physical      Horizon    MICROFORM          2024              9
# 258   Physical      Horizon    MICROFORM          2024             10
# 259   Physical      Horizon    MICROFORM          2024             10
#
#      checkouts                                              title  isbn  \
# ...

# %%
year = microf_df["checkoutyear"].value_counts().sort_index()
year
# Out:
# checkoutyear
# 2005    13
# 2006    23
# 2007    30
# 2008     9
# 2009    17
# 2010    16
# 2011    19
# 2012     6
# 2013     5
# 2014     8
# 2015    10
# 2016     3
# 2017     4
# 2018    20
# 2019    28
# 2020     5
# 2021    13
# 2022    11
# 2023    10
# 2024    10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

year.plot(color='turquoise')
ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
plt.xlim([2005, 2023])
plt.ylabel('Ausleihzahlen')
plt.title('Ausleihhäufigkeit von Mikroformen 2005-2023')
# Out:
# Text(0.5, 1.0, 'Ausleihhäufigkeit von Mikroformen 2005-2023')
